# %%
import pandas as pd

# %%
df1=pd.read_csv(r"C:\Users\neela\Downloads\fear_greed_index.csv")
df2=pd.read_csv(r"C:\Users\neela\Downloads\historical_data.csv")

# %%
df1.head(20)
# Out:
#      timestamp  value classification        date
# 0   1517463000     30           Fear  2018-02-01
# 1   1517549400     15   Extreme Fear  2018-02-02
# 2   1517635800     40           Fear  2018-02-03
# 3   1517722200     24   Extreme Fear  2018-02-04
# 4   1517808600     11   Extreme Fear  2018-02-05
# 5   1517895000      8   Extreme Fear  2018-02-06
# 6   1517981400     36           Fear  2018-02-07
# 7   1518067800     30           Fear  2018-02-08
# 8   1518154200     44           Fear  2018-02-09
# 9   1518240600     54        Neutral  2018-02-10
# 10  1518327000     31           Fear  2018-02-11
# 11  1518413400     42           Fear  2018-02-12
# 12  1518499800     35           Fear  2018-02-13
# 13  1518586200     55          Greed  2018-02-14
# 14  1518672600     71          Greed  2018-02-15
# 15  1518759000     67          Greed  2018-02-16
# 16  1518845400     74          Greed  2018-02-17
# 17  1518931800     63          Greed  2018-02-18
# ...

# %%
df2.head(5)
# Out:
#                                       Account  Coin  Execution Price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
# 2  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9855
# 3  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9874
# 4  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9894
#
#    Size Tokens  Size USD Side     Timestamp IST  Start Position Direction  \
# 0       986.87   7872.16  BUY  02-12-2024 22:50        0.000000       Buy
# 1        16.00    127.68  BUY  02-12-2024 22:50      986.524596       Buy
# 2       144.09   1150.63  BUY  02-12-2024 22:50     1002.518996       Buy
# 3       142.98   1142.04  BUY  02-12-2024 22:50     1146.558564       Buy
# 4         8.73     69.75  BUY  02-12-2024 22:50     1289.488521       Buy
#
#    Closed PnL                                   Transaction Hash     Order ID  \
# ...

# %%
df1.isnull().sum()
# Out:
# timestamp         0
# value             0
# classification    0
# date              0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2644 entries, 0 to 2643
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp       2644 non-null   int64
#  1   value           2644 non-null   int64
#  2   classification  2644 non-null   object
#  3   date            2644 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 82.8+ KB

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1['date']=pd.to_datetime(df1['date'])

# %%
df2.isnull().sum()
# Out:
# Account             0
# Coin                0
# Execution Price     0
# Size Tokens         0
# Size USD            0
# Side                0
# Timestamp IST       0
# Start Position      0
# Direction           0
# Closed PnL          0
# Transaction Hash    0
# Order ID            0
# Crossed             0
# Fee                 0
# Trade ID            0
# Timestamp           0
# dtype: int64

# %%
df2.head(2)
# Out:
#                                       Account  Coin  Execution Price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
#
#    Size Tokens  Size USD Side     Timestamp IST  Start Position Direction  \
# 0       986.87   7872.16  BUY  02-12-2024 22:50        0.000000       Buy
# 1        16.00    127.68  BUY  02-12-2024 22:50      986.524596       Buy
#
#    Closed PnL                                   Transaction Hash     Order ID  \
# 0         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
# 1         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
#
#    Crossed       Fee      Trade ID     Timestamp
# 0     True  0.345404  8.950000e+14  1.730000e+12
# 1     True  0.005600  4.430000e+14  1.730000e+12

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211224 entries, 0 to 211223
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Account           211224 non-null  object
#  1   Coin              211224 non-null  object
#  2   Execution Price   211224 non-null  float64
#  3   Size Tokens       211224 non-null  float64
#  4   Size USD          211224 non-null  float64
#  5   Side              211224 non-null  object
#  6   Timestamp IST     211224 non-null  object
#  7   Start Position    211224 non-null  float64
#  8   Direction         211224 non-null  object
#  9   Closed PnL        211224 non-null  float64
#  10  Transaction Hash  211224 non-null  object
#  11  Order ID          211224 non-null  int64
#  12  Crossed           211224 non-null  bool
#  13  Fee               211224 non-null  float64
#  14  Trade ID          211224 non-null  float64
# ...

# %%
df2.columns
# Out:
# Index(['Account', 'Coin', 'Execution Price', 'Size Tokens', 'Size USD', 'Side',
#        'Timestamp IST', 'Start Position', 'Direction', 'Closed PnL',
#        'Transaction Hash', 'Order ID', 'Crossed', 'Fee', 'Trade ID',
#        'Timestamp'],
#       dtype='object')

# %%
df2['Timestamp IST'] = pd.to_datetime(df2['Timestamp IST'], format='%d-%m-%Y %H:%M')

# %%
df2['Timestamp'] = pd.to_datetime(df2['Timestamp'], unit='ms')

# %%
df2.head(2)
# Out:
#                                       Account  Coin  Execution Price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
#
#    Size Tokens  Size USD Side       Timestamp IST  Start Position Direction  \
# 0       986.87   7872.16  BUY 2024-12-02 22:50:00        0.000000       Buy
# 1        16.00    127.68  BUY 2024-12-02 22:50:00      986.524596       Buy
#
#    Closed PnL                                   Transaction Hash     Order ID  \
# 0         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
# 1         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
#
#    Crossed       Fee      Trade ID           Timestamp
# 0     True  0.345404  8.950000e+14 2024-10-27 03:33:20
# 1     True  0.005600  4.430000e+14 2024-10-27 03:33:20

# %%
df1['date'] = pd.to_datetime(df1['date']).dt.date

# %%
df2['date'] = pd.to_datetime(df2['Timestamp']).dt.date

# %%
df2.columns
# Out:
# Index(['Account', 'Coin', 'Execution Price', 'Size Tokens', 'Size USD', 'Side',
#        'Timestamp IST', 'Start Position', 'Direction', 'Closed PnL',
#        'Transaction Hash', 'Order ID', 'Crossed', 'Fee', 'Trade ID',
#        'Timestamp', 'date'],
#       dtype='object')

# %%
m=pd.merge(df1,df2,on='date',how='outer')

# %%
daily_pnl = df2.groupby(['date','Account'])['Closed PnL'].sum().reset_index()

# %%
daily_pnl
# Out:
#            date                                     Account     Closed PnL
# 0    2023-03-28  0x3998f134d6aaa2b6a5f723806d00fd2bbbbce891       0.000000
# 1    2023-11-14  0x3998f134d6aaa2b6a5f723806d00fd2bbbbce891       0.000000
# 2    2023-11-14  0xb1231a4a2dd02f2276fa3c5e2a2f3436e6bfed23     155.503357
# 3    2024-03-09  0x3998f134d6aaa2b6a5f723806d00fd2bbbbce891   -5564.016140
# 4    2024-03-09  0x430f09841d65beb3f27765503d0f850b8bce7713       0.000000
# ..          ...                                         ...            ...
# 97   2025-06-15  0xae5eacaf9c6b9111fd53034a602c192a04e082ed   38168.354860
# 98   2025-06-15  0xb1231a4a2dd02f2276fa3c5e2a2f3436e6bfed23  102460.171640
# 99   2025-06-15  0xbaaaf6571ab7d571043ff1e313a9609a10637864       6.593538
# 100  2025-06-15  0xbd5fead7180a9c139fa51a103cb6a2ce86ddb5c3 -116594.595363
# 101  2025-06-15  0xbee1707d6b44d4d52bfe19e41f8a828645437aab   24897.574309
#
# [102 rows x 3 columns]

# %% [markdown]
# # win rate

# %%
win_rate=(df2['Closed PnL'] > 0).mean()

# %%
win_rate
# Out:
# 0.4112648183918494

# %% [markdown]
# # average trade size

# %%
avg_trade_size=df2['Size USD'].mean()

# %%
avg_trade_size
# Out:
# 5639.4512103738225

# %% [markdown]
# # leverage distribution

# %% [markdown]
# # number of trades per day

# %%
num_trades_day= df2.groupby('date').size().reset_index(name='num_trades')

# %%
num_trades_day
# Out:
#          date  num_trades
# 0  2023-03-28           3
# 1  2023-11-14        1045
# 2  2024-03-09        6962
# 3  2024-07-03        7141
# 4  2024-10-27       35241
# 5  2025-02-19      133871
# 6  2025-06-15       26961

# %% [markdown]
# # long/short ratio

# %%
long=(df2['Direction']=='Buy').sum()
short=(df2['Direction']=='Sell').sum()

# %% [raw]
# # RATIO

# %%
ratio=long/(long + short)

# %%
ratio*100
# Out:
# 45.64968048500737

# %% [markdown]
# # ANALYSIS

# %% [raw]
# Q1=Does performance (PnL, win rate, drawdown proxy) differ between Fear vs Greed days?

# %%
# LETS TAKE ON AVG

# %%
m1=pd.merge(df2, df1[['date','classification']], on='date', how='left')

# %%
(m1.groupby('classification')['Closed PnL'].mean().nlargest(2))
# Out:
# classification
# Greed    87.894859
# Fear     50.047622
# Name: Closed PnL, dtype: float64

# %%
(m1.groupby('classification')['Closed PnL'].apply(lambda x: (x > 0).mean()))*100
# Out:
# classification
# Extreme Greed    49.008905
# Fear             41.514592
# Greed            44.647138
# Neutral          31.718247
# Name: Closed PnL, dtype: float64

# %%
(m1.groupby('classification')['Closed PnL'].apply(lambda x: x[x < 0].mean()))
# Out:
# classification
# Extreme Greed    -86.703571
# Fear            -150.445182
# Greed           -178.268548
# Neutral         -301.002712
# Name: Closed PnL, dtype: float64

# %%
# YES  performance (PnL, win rate, drawdown proxy) differ between Fear vs Greed days

# %% [raw]
# Q2 = Do traders change behavior based on sentiment (trade frequency, leverage, long/short bias, position sizes)

# %%
(m1.groupby('classification').size()).sort_values(ascending=False)
# Out:
# classification
# Fear             133871
# Greed             36289
# Neutral            7141
# Extreme Greed      6962
# dtype: int64

# %%
(m1.groupby('classification')['Size USD'].mean())
# Out:
# classification
# Extreme Greed    5660.265764
# Fear             5259.977837
# Greed            3182.883845
# Neutral          3058.848110
# Name: Size USD, dtype: float64

# %%
(m1.groupby('classification')['Direction'].apply(lambda x: (x == 'Buy').mean()))
# Out:
# classification
# Extreme Greed    0.012640
# Fear             0.059587
# Greed            0.159993
# Neutral          0.110069
# Name: Direction, dtype: float64

# %% [raw]
# On Fear days traders are far more active and take bigger positions, but mostly short. On Greed days they trade less, with smaller positions, and show a stronger long bias

# %%
df1.columns
# Out:
# Index(['timestamp', 'value', 'classification', 'date'], dtype='object')

# %%
df2.columns
# Out:
# Index(['Account', 'Coin', 'Execution Price', 'Size Tokens', 'Size USD', 'Side',
#        'Timestamp IST', 'Start Position', 'Direction', 'Closed PnL',
#        'Transaction Hash', 'Order ID', 'Crossed', 'Fee', 'Trade ID',
#        'Timestamp', 'date'],
#       dtype='object')
